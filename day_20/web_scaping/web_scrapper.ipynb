# %% [markdown]
# ### Web Scraper -

# %%
# !pip install requests

# %%
# !pip install bs4

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone15"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone15'

# %%
urlclient = urlopen(flipkart_url)
urlclient

# %%
# read the url page
flipkart_page = urlclient.read()
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %% [markdown]
# ##### Tring to convert this html data into readable format. So we use beautiful soup.

# %%
flipkart_html = bs(flipkart_page , 'html.parser')
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# Suppose this is a specific product,

# %%
"https://www.flipkart.com"+"/apple-iphone-15-green-128-gb/p/itm235cd318bde73?pid=MOBGTAGPYYWZRUJX&lid=LSTMOBGTAGPYYWZRUJXXIP6YM&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&srno=s_1_3&otracker=search&iid=a2de5b05-a236-4b58-9998-9fb38e4b8a8a.MOBGTAGPYYWZRUJX.SEARCH&ssid=wc5t4ofcao0000001712683812360&qH=1827ac0d826493c5"
# Out:
# 'https://www.flipkart.com/apple-iphone-15-green-128-gb/p/itm235cd318bde73?pid=MOBGTAGPYYWZRUJX&lid=LSTMOBGTAGPYYWZRUJXXIP6YM&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&srno=s_1_3&otracker=search&iid=a2de5b05-a236-4b58-9998-9fb38e4b8a8a.MOBGTAGPYYWZRUJX.SEARCH&ssid=wc5t4ofcao0000001712683812360&qH=1827ac0d826493c5'

# %% [markdown]
# #### If we want to fetch only this above product. then in the website,click `Fn + F12` we can `inspect` the browser html and select the `div class id` of the product. then fetch the data.
# class id- _1AtVbE col-12-12

# %%
bigbox = flipkart_html.find_all("div" ,{"class":"_1AtVbE col-12-12"} )
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone15&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
len(bigbox)
# Out:
# 30

# %%
# we want to fetch the data of this iphone product
bigbox[3]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGTAGPYYWZRUJX" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-15-green-128-gb/p/itm235cd318bde73?pid=MOBGTAGPYYWZRUJX&amp;lid=LSTMOBGTAGPYYWZRUJXXIP6YM&amp;marketplace=FLIPKART&amp;q=iphone15&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=f7628ade-250b-4f79-b4da-fb02c061f3b7.MOBGTAGPYYWZRUJX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=7tmjdtnvlc0000001712685534828&amp;qH=1827ac0d826493c5" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 15 (Green, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/j/z/3/-original-imagtc5fqyz8tu4c.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbo
# ...

# %%
del bigbox[0:3]

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGTAGPYYWZRUJX" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-15-green-128-gb/p/itm235cd318bde73?pid=MOBGTAGPYYWZRUJX&amp;lid=LSTMOBGTAGPYYWZRUJXXIP6YM&amp;marketplace=FLIPKART&amp;q=iphone15&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=f7628ade-250b-4f79-b4da-fb02c061f3b7.MOBGTAGPYYWZRUJX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=7tmjdtnvlc0000001712685534828&amp;qH=1827ac0d826493c5" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 15 (Green, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/j/z/3/-original-imagtc5fqyz8tu4c.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkb
# ...

# %%
bigbox[0].div.div.div.a['href']
# Out:
# '/apple-iphone-15-green-128-gb/p/itm235cd318bde73?pid=MOBGTAGPYYWZRUJX&lid=LSTMOBGTAGPYYWZRUJXXIP6YM&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=f7628ade-250b-4f79-b4da-fb02c061f3b7.MOBGTAGPYYWZRUJX.SEARCH&ppt=None&ppn=None&ssid=7tmjdtnvlc0000001712685534828&qH=1827ac0d826493c5'

# %%
productlink = "https://www.flipkart.com" + bigbox[0].div.div.div.a['href']
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-15-green-128-gb/p/itm235cd318bde73?pid=MOBGTAGPYYWZRUJX&lid=LSTMOBGTAGPYYWZRUJXXIP6YM&marketplace=FLIPKART&q=iphone15&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=f7628ade-250b-4f79-b4da-fb02c061f3b7.MOBGTAGPYYWZRUJX.SEARCH&ppt=None&ppn=None&ssid=7tmjdtnvlc0000001712685534828&qH=1827ac0d826493c5'

# %%
product_req = requests.get(productlink)

# %%
# product_req

# %%
product_html = bs(product_req.text,'html.parser')

# %%
comment_box = product_html.find_all("div",{"class":"_2c2kV-"})

# %%
len(comment_box)
# Out:
# 11
